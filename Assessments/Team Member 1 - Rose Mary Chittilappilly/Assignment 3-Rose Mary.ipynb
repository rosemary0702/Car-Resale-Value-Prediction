# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Dataset has been downloaded

# %%
#name:- abalone.csv

# %% [markdown]
# # 2. Load the dataset into the tool

# %%
data=pd.read_csv("abalone.csv")
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # 3. Perform Below Visualizations.

# %% [markdown]
# ## (i) Univariate Analysis

# %%
sns.displot(data["Height"], color='pink')

# %%
sns.histplot(y=data.Length,color='blue')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Length'>

# %%
sns.histplot(x=data.Length,color='orange')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Count'>

# %%
sns.boxplot(x=data.Height,color='pink')
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.countplot(x=data.Height)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='count'>

# %% [markdown]
# ## (ii) Bi-Variate Analysis

# %%
sns.barplot(x=data.Height,y=data.Length)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Length'>

# %%
sns.lineplot(x=data.Height,y=data.Length, color='yellow')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Length'>

# %%
sns.scatterplot(x=data.Height,y=data.Length,color='purple')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Length'>

# %%
sns.pointplot(x=data.Height, y=data.Length, color="blue")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Length'>

# %% [markdown]
# ## (iii) Multi-Variate Analysis

# %%
data=data.rename(columns = {'Whole weight':'Whole_weight','Shucked weight': 'Shucked_weight','Viscera weight': 'Viscera_weight',
                            'Shell weight': 'Shell_weight'})

# %%
sns.pairplot(data=data[["Height","Length","Diameter","Whole_weight","Shucked_weight","Viscera_weight","Shell_weight"]])

# %%
sns.pairplot(data=data[["Height","Length","Diameter","Whole_weight","Shucked_weight","Viscera_weight","Shell_weight"]],kind="kde")

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Perform descriptive statistics on the dataset.

# %%
data.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole_weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked_weight  Viscera_weight  Shell_weight        Rings
# count      4177.000000     4177.000000   4177.000000  4177.000000
# ...

# %%
data.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Length          4177.0  0.523992  0.120093  0.0750  0.4500  0.5450   0.615
# Diameter        4177.0  0.407881  0.099240  0.0550  0.3500  0.4250   0.480
# Height          4177.0  0.139516  0.041827  0.0000  0.1150  0.1400   0.165
# Whole_weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked_weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera_weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell_weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Length           0.8150
# Diameter         0.6500
# Height           1.1300
# Whole_weight     2.8255
# Shucked_weight   1.4880
# Viscera_weight   0.7600
# Shell_weight     1.0050
# Rings           29.0000

# %% [markdown]
# # 5. Check for Missing values and deal with them.

# %%
data.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # 6. Find the outliers and replace them outliers

# %%
data['Sex'].replace({'M':1, 'F':0, 'I':-1},inplace=True)
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    1   0.455     0.365   0.095        0.5140          0.2245
# 1    1   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    1   0.440     0.365   0.125        0.5160          0.2155
# 4   -1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
data.Sex.unique()
# Out:
# array([ 1,  0, -1])

# %%
sns.boxplot(x=data["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
sns.boxplot(x=data["Length"])
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(x=data["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(x=data["Height"])
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(x=data["Whole_weight"])
# Out:
# <AxesSubplot:xlabel='Whole_weight'>

# %%
sns.boxplot(x=data["Shucked_weight"])
# Out:
# <AxesSubplot:xlabel='Shucked_weight'>

# %%
sns.boxplot(x=data["Viscera_weight"])
# Out:
# <AxesSubplot:xlabel='Viscera_weight'>

# %%
sns.boxplot(x=data["Shell_weight"])
# Out:
# <AxesSubplot:xlabel='Shell_weight'>

# %%
sns.boxplot(x=data["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings'>

# %%
#handle outlier
qnt=data.quantile(q=[0.25,0.75])
qnt
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0.25 -1.0   0.450      0.35   0.115        0.4415           0.186
# 0.75  1.0   0.615      0.48   0.165        1.1530           0.502
#
#       Viscera_weight  Shell_weight  Rings
# 0.25          0.0935         0.130    8.0
# 0.75          0.2530         0.329   11.0

# %%
iqr=qnt.loc[0.75]-qnt.loc[0.25]
iqr
# Out:
# Sex               2.0000
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole_weight      0.7115
# Shucked_weight    0.3160
# Viscera_weight    0.1595
# Shell_weight      0.1990
# Rings             3.0000
# dtype: float64

# %%
#lower limit
lower=qnt.loc[0.25]-(1.5*iqr)
lower
# Out:
# Sex              -4.00000
# Length            0.20250
# Diameter          0.15500
# Height            0.04000
# Whole_weight     -0.62575
# Shucked_weight   -0.28800
# Viscera_weight   -0.14575
# Shell_weight     -0.16850
# Rings             3.50000
# dtype: float64

# %%
#upper limit
upper=qnt.loc[0.75]+(1.5*iqr)
upper
# Out:
# Sex                4.00000
# Length             0.86250
# Diameter           0.67500
# Height             0.24000
# Whole_weight       2.22025
# Shucked_weight     0.97600
# Viscera_weight     0.49225
# Shell_weight       0.62750
# Rings             15.50000
# dtype: float64

# %%
data.mean()
# Out:
# Sex               0.044530
# Length            0.523992
# Diameter          0.407881
# Height            0.139516
# Whole_weight      0.828742
# Shucked_weight    0.359367
# Viscera_weight    0.180594
# Shell_weight      0.238831
# Rings             9.933684
# dtype: float64

# %%
#replace outlier
data['Length']=np.where(data['Length']<0.22,0.52,data['Length'])
data['Diameter']=np.where(data['Diameter']<0.155,0.407,data['Diameter'])
data['Height']=np.where(data['Height']<0.04,0.13,data['Height'])
data['Height']=np.where(data['Height']>0.24,0.13,data['Height'])
data['Whole_weight']=np.where(data['Whole_weight']>2.18,0.83,data['Whole_weight'])
data['Shucked_weight']=np.where(data['Shucked_weight']>0.958,0.359367,data['Shucked_weight'])
data['Viscera_weight']=np.where(data['Viscera_weight']>0.478,0.18,data['Viscera_weight'])
data['Shell_weight']=np.where(data['Shell_weight']>0.61,0.238831,data['Shell_weight'])
data['Rings']=np.where(data['Rings']<3.5,9.93,data['Rings'])
data['Rings']=np.where(data['Rings']>15.5,9.93,data['Rings'])

# %%
sns.boxplot(data['Length'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(data['Diameter'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(data['Height'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(data['Whole_weight'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Whole_weight'>

# %%
sns.boxplot(data['Shucked_weight'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shucked_weight'>

# %%
sns.boxplot(data['Viscera_weight'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Viscera_weight'>

# %%
sns.boxplot(data['Shell_weight'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell_weight'>

# %%
sns.boxplot(data['Rings'])
# Out:
# /Users/rosemarychittilappilly/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings'>

# %% [markdown]
# # 7. Check for Categorical columns and perform encoding.

# %%
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    1   0.455     0.365   0.095        0.5140          0.2245
# 1    1   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    1   0.440     0.365   0.125        0.5160          0.2155
# 4   -1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150   15.0
# 1          0.0485         0.070    7.0
# 2          0.1415         0.210    9.0
# 3          0.1140         0.155   10.0
# 4          0.0395         0.055    7.0

# %% [markdown]
# # 8. Split the data into dependent and independent variables.

# %%
x=data.drop(columns=['Rings'],axis=1).values
x
# Out:
# array([[1.    , 0.455 , 0.365 , ..., 0.2245, 0.101 , 0.15  ],
#        [1.    , 0.35  , 0.265 , ..., 0.0995, 0.0485, 0.07  ],
#        [0.    , 0.53  , 0.42  , ..., 0.2565, 0.1415, 0.21  ],
#        ...,
#        [1.    , 0.6   , 0.475 , ..., 0.5255, 0.2875, 0.308 ],
#        [0.    , 0.625 , 0.485 , ..., 0.531 , 0.261 , 0.296 ],
#        [1.    , 0.71  , 0.555 , ..., 0.9455, 0.3765, 0.495 ]])

# %%
y=data['Rings'].values
y
# Out:
# array([15.,  7.,  9., ...,  9., 10., 12.])

# %%
a = data["Sex"]
a.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4   -1
# Name: Sex, dtype: int64

# %%
b=data.drop(columns=["Sex"],axis=1)
b.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150   15.0
# 1         0.070    7.0
# 2         0.210    9.0
# 3         0.155   10.0
# 4         0.055    7.0

# %% [markdown]
# # 9. Scale the independent variables

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(b), columns=b.columns)
X_Scaled.head()
# Out:
#      Length  Diameter    Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0 -0.663474 -0.501673 -1.196422     -0.643390       -0.611770       -0.732343
# 1 -1.601273 -1.572915 -1.330241     -1.259765       -1.219694       -1.236126
# 2  0.006383  0.087510 -0.125873     -0.295144       -0.456142       -0.343709
# 3 -0.797445 -0.501673 -0.393511     -0.639118       -0.655541       -0.607596
# 4 -1.779901 -1.680039 -1.597878     -1.303563       -1.268328       -1.322489
#
#    Shell_weight     Rings
# 0     -0.643590  2.408000
# 1     -1.257424 -1.059385
# 2     -0.183214 -0.192539
# 3     -0.605225  0.240884
# 4     -1.372518 -1.059385

# %%
x=scale(x)
x
# Out:
# array([[-0.66347373, -0.50167301, -1.19642227, ..., -0.73234257,
#         -0.64358992,  2.40800029],
#        [-1.60127264, -1.57291477, -1.33024088, ..., -1.23612645,
#         -1.25742425, -1.05938498],
#        [ 0.00638264,  0.08750996, -0.12587343, ..., -0.34370929,
#         -0.18321418, -0.19253867],
#        ...,
#        [ 0.63158191,  0.67669293,  1.74758705, ...,  1.05728969,
#          0.56873287, -0.19253867],
#        [ 0.85486737,  0.78381711,  0.27558239, ...,  0.80299878,
#          0.47665772,  0.24088449],
#        [ 1.61403792,  1.53368634,  1.47994984, ...,  1.91132331,
#          2.0035706 ,  1.10773081]])

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_Scaled, y, test_size=0.2, random_state=0)

# %%
X_Train.shape,X_Test.shape
# Out:
# ((3341, 8), (836, 8))

# %%
Y_Train.shape,Y_Test.shape
# Out:
# ((3341,), (836,))

# %%
X_Train.head()
# Out:
#         Length  Diameter    Height  Whole_weight  Shucked_weight  \
# 3141 -0.082932 -0.051751 -1.597878     -1.671037       -1.633082
# 3521 -0.082932 -0.051751 -2.266971     -1.653946       -1.630650
# 883   1.167467  1.265876  0.810857      1.229234        1.168230
# 3627  1.658695  1.212314  1.613768      2.296406        2.916618
# 2106  0.586925  0.462445  0.409401      0.482535        0.319569
#
#       Viscera_weight  Shell_weight     Rings
# 3141       -1.634356     -1.717800 -1.926231
# 3521       -1.615164     -1.698618  0.210545
# 883         0.332800      1.681308  2.408000
# 3627        2.482278      1.508667  0.240884
# 2106        0.318407      1.006090  1.974577

# %%
X_Test.head()
# Out:
#         Length  Diameter    Height  Whole_weight  Shucked_weight  \
# 668   0.185011  0.141072  0.409401      0.218679       -0.354011
# 1580 -0.261560 -0.126738 -0.527329     -0.425469       -0.434257
# 3784  0.810210  0.730255  0.409401      0.940810        0.859405
# 463  -2.762357 -2.644157 -2.266971     -1.625103       -1.599038
# 2615  1.033496  0.944503  0.944675      1.485612        1.571891
#
#       Viscera_weight  Shell_weight     Rings
# 668         0.630273      0.775902  1.541154
# 1580       -0.329315     -0.309818 -0.625962
# 3784        1.887334      0.641626  0.674308
# 463        -1.586376     -1.641071 -1.926231
# 2615        1.901727      1.102001  1.107731

# %%
Y_Train.head()
# Out:
# 3141   -1
# 3521   -1
# 883     1
# 3627    1
# 2106    1
# Name: Sex, dtype: int64

# %%
Y_Test.head()
# Out:
# 668     1
# 1580   -1
# 3784    1
# 463    -1
# 2615    1
# Name: Sex, dtype: int64

# %% [markdown]
# # 11. Build the Model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
model.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predict = model.predict(X_Test)

# %%
y_predict_train = model.predict(X_Train)

# %% [markdown]
# # 12. Train the Model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Training accuracy: ',accuracy_score(Y_Train,y_predict_train))
# Out:
# Training accuracy:  0.9802454354983537

# %% [markdown]
# # 13. Test the Model

# %%
print('Testing accuracy: ',accuracy_score(Y_Test,y_predict))
# Out:
# Testing accuracy:  0.527511961722488

# %% [markdown]
# # 14. Measure the performance using Metrics.

# %%
pd.crosstab(Y_Test,y_predict)
# Out:
# col_0   -1    0    1
# Sex
# -1     224   34   33
#  0      38  110  101
#  1      66  123  107

# %%
print(classification_report(Y_Test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.68      0.77      0.72       291
#            0       0.41      0.44      0.43       249
#            1       0.44      0.36      0.40       296
#
#     accuracy                           0.53       836
#    macro avg       0.51      0.52      0.52       836
# weighted avg       0.52      0.53      0.52       836
